# %% [markdown]
# <div style="background-color: lightblue; padding: 20px; text-align: center; border-radius: 10px;">
#     <h1 style="color: beige; font-weight: bold;">
#         &#8226;&#8226;
#         <span style="color: beige;"> Loan Prediction </span>
#         &#8226;&#8226;
#     </h1>
# </div>
#
# <span style="color: beige;"> suan burda lazim degil Classification</span>

# %% [raw]
# Bu projede, bir finansal kurum tarafından sağlanan veri seti kullanılarak, kredi temerrüt riski düşük olan müşterileri tanımlayan bir Classification modeli geliştireceğiz. Veri seti, kredi durumu, mevcut kredi miktarı, kredi puanı ve mevcut işteki yıllar gibi çeşitli müşteri özelliklerini içermektedir. Hedef, iyi müşterileri tanıyacak bir model eğitmek ve bu modele dayalı olarak kredi başvuruları için spesifik sorular geliştirmektir. Veri hazırlığı aşamasında, eksik değerler, yazım hataları ve yinelenen veriler gibi zorluklarla başa çıkılacaktır.
# _______
# This dataset is from a financial institution to develop a classification model that identifies customers with a lower risk of loan default. The dataset includes features like loan status, credit score, and years in the current job. The goal is to train the model to identify good customers and generate specific questions for loan applications. Data preparation will address challenges such as missing values and duplicates to ready the dataset for modeling

# %% [markdown]
# **Data Dictionary**
#
# | **Column Name**                    | **Description**                                                                    | **Turkish Translation**           |
# |------------------------------------|------------------------------------------------------------------------------------|-----------------------------------|
# | Loan ID                            | A unique identifier for each loan.                                                 | Kredi Kimliği                     |
# | Customer ID                        | A unique identifier for each customer.                                             | Müşteri Kimliği                   |
# | Loan Status                        | The current state of the loan (e.g., approved, denied).                            | Kredi Durumu                      |
# | Current Loan Amount                | The total amount of money currently borrowed.                                      | Mevcut Kredi Miktarı              |
# | Term                               | The duration of the loan (e.g., number of months).                                 | Kredi Süresi                      |
# | Credit Score                       | A numerical representation of a borrower's creditworthiness.                       | Kredi Puanı                       |
# | Years in Current Job               | The number of years the customer has been employed in their current job.           | Mevcut İşte Çalışılan Yıl Sayısı  |
# | Home Ownership                     | Indicates whether the customer owns their home, rents, or has another arrangement  | Ev Sahipliği                      |
# | Annual Income                      | The total income earned by the customer in a year.                                 | Yıllık Gelir                      |
# | Purpose                            | The reason for taking out the loan (e.g., home improvement).                       | Amaç                              |
# | Monthly Debt                       | The total amount of debt the customer is responsible for each month.               | Aylık Borç                        |
# | Years of Credit History            | The length of time the customer has had credit accounts.                           | Kredi Geçmişi Yılı                |
# | Months Since Last Delinquent Payment | The number of months since the customer last made a late payment.                | Son Gecikmeli Ödeme Ayları        |
# | Number of Open Accounts            | The total number of credit accounts the customer currently has open.               | Açık Hesap Sayısı                 |
# | Number of Credit Problems          | The total number of issues related to the customer's credit history.               | Kredi Sorunları Sayısı            |
# | Current Credit Balance             | The total amount of credit the customer is using.                                  | Mevcut Kredi Bakiyesi             |
# | Maximum Open Credit                | The highest amount of credit that has been available at any one time.              | Maksimum Açık Kredi Miktarı       |
# | Bankruptcies                       | The number of times the customer has declared bankruptcy.                          | İflas Sayısı                      |
# | Tax Liens                          | The number of tax liens filed against the customer.                                | Vergi İhtilafları Sayısı          |

# %% [markdown]
# <img src='https://miro.medium.com/v2/resize:fit:1200/1*7T7vIQyQgYcK-ao7eHcK_g.jpeg'>
# <a href='https://classroom.google.com/c/NzIwMjcyMjkxMjgy/a/NzIwMjcyMjkxNDQ0/details' target=_blank>
# Click here for the dataset </a>

# %% [markdown]
# **Import library**

# %%
import pandas as pd 
pd.set_option("display.max_columns",55)
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('LoansTrainingSet.csv')

# %%
pwd
# Out:
# 'C:\\Users\\YSelim\\Documents\\Ki2.0\\Project Based One\\3 - Loan Prediction - Classification'

# %% [markdown]
# **EDA - Exploratory Data Analysis**

# %%
df.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  000025bb-5694-4cff-b17d-192b1a98ba44  5ebc8bb1-5eb9-4404-b11b-a6eebc401a19
# 1  00002c49-3a29-4bd4-8f67-c8f8fbc1048c  927b388d-2e01-423f-a8dc-f7e42d668f46
# 2  00002d89-27f3-409b-aa76-90834f359a65  defce609-c631-447d-aad6-1270615e89c4
# 3  00005222-b4d8-45a4-ad8c-186057e24233  070bcecb-aae7-4485-a26a-e0403e7bb6c5
# 4  0000757f-a121-41ed-b17b-162e76647c1f  dde79588-12f0-4811-bab0-e2b07f633fcd
#
#   Loan Status  Current Loan Amount        Term  Credit Score  \
# 0  Fully Paid                11520  Short Term         741.0
# 1  Fully Paid                 3441  Short Term         734.0
# 2  Fully Paid                21029  Short Term         747.0
# 3  Fully Paid                18743  Short Term         747.0
# 4  Fully Paid                11731  Short Term         746.0
#
#   Years in current job Home Ownership  Annual Income             Purpose  \
# ...

# %%
df.shape
# Out:
# (256984, 19)

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (240374, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 240374 entries, 0 to 256983
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       240374 non-null  object
#  1   Customer ID                   240374 non-null  object
#  2   Loan Status                   240374 non-null  object
#  3   Current Loan Amount           240374 non-null  int64
#  4   Term                          240374 non-null  object
#  5   Credit Score                  181028 non-null  float64
#  6   Years in current job          229930 non-null  object
#  7   Home Ownership                240374 non-null  object
#  8   Annual Income                 181028 non-null  float64
#  9   Purpose                       240374 non-null  object
#  10  Monthly Debt                  240374 non-null  object
#  11  Years of Credit History       240374 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Loan ID                              0
# Customer ID                          0
# Loan Status                          0
# Current Loan Amount                  0
# Term                                 0
# Credit Score                     59346
# Years in current job             10444
# Home Ownership                       0
# Annual Income                    59346
# Purpose                              0
# Monthly Debt                         0
# Years of Credit History              0
# Months since last delinquent    131427
# Number of Open Accounts              0
# Number of Credit Problems            0
# Current Credit Balance               0
# Maximum Open Credit                  0
# Bankruptcies                       492
# Tax Liens                           23
# dtype: int64

# %%
df.describe()
# Out:
#        Current Loan Amount   Credit Score  Annual Income  \
# count         2.403740e+05  181028.000000   1.810280e+05
# mean          1.465988e+07    1236.274079   7.240027e+04
# std           3.535384e+07    1737.765627   5.646808e+04
# min           5.050000e+02     585.000000   0.000000e+00
# 25%           8.300250e+03     715.000000   4.455500e+04
# 50%           1.439400e+04     734.000000   6.150500e+04
# 75%           2.456600e+04     744.000000   8.705700e+04
# max           1.000000e+08    7510.000000   8.713547e+06
#
#        Years of Credit History  Months since last delinquent  \
# count            240374.000000                 108947.000000
# mean                 18.310392                     34.939191
# std                   7.067637                     21.844115
# min                   3.400000                      0.000000
# 25%                  13.500000                     16.000000
# 50%                  17.000000                     32.000000
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                               Current Loan Amount  Credit Score  \
# Current Loan Amount                      1.000000     -0.144272
# Credit Score                            -0.144272      1.000000
# Annual Income                            0.022396     -0.035725
# Years of Credit History                  0.014140     -0.013987
# Months since last delinquent             0.002546     -0.010896
# Number of Open Accounts                 -0.002482      0.009175
# Number of Credit Problems                0.000523      0.001247
# Current Credit Balance                   0.003020     -0.003235
# Bankruptcies                             0.003888     -0.003536
# Tax Liens                               -0.002788      0.005229
#
#                               Annual Income  Years of Credit History  \
# Current Loan Amount                0.022396                 0.014140
# Credit Score                      -0.035725                -0.013987
# ...

# %% [markdown]
# **Data Visualization**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x=df['Term']);

# %%
# Creating multiple subplots
fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# Countplot für 'Loan Status'
sns.countplot(x='Loan Status', data=df, palette='pastel', ax=axes[0])
axes[0].set_title('Loan Status')
axes[0].set_xlabel('Loan Status')
axes[0].set_ylabel('Count')
# Add the result statement as text below the plot
axes[0].text(0.5, -0.15, 
             f"Overall, there are more loans that have been fully repaid than loans that have defaulted", 
             ha='center', va='center', transform=axes[0].transAxes)

# Countplot für 'Home Ownership'
sns.countplot(x='Home Ownership', data=df, palette='muted', ax=axes[1])
axes[1].set_title('Home Ownership')
axes[1].set_xlabel('Home Ownership')
axes[1].set_ylabel('Count')
# Add the result statement as text below the plot
axes[1].text(0.5, -0.15, 
             f"There are more borrowers with a 'Home Mortgage' ({mortgage_count}) than those who 'Rent' ({rent_count}).", 
             ha='center', va='center', transform=axes[1].transAxes)

# Countplot für 'Purpose'
sns.countplot(x='Term', data=df,palette='spring', ax=axes[2])
axes[2].set_title('Term')
axes[2].set_xlabel('Term')
axes[2].set_ylabel('Term')

plt.tight_layout()
plt.show()

# %%
# Countplot for 'Purpose'
plt.figure(figsize=(10, 6))
sns.countplot(x='Purpose', data=df, palette='spring')
plt.title('Distribution of Loan Purposes')
plt.xlabel('Loan Purpose')
plt.ylabel('Number of Loans')
plt.xticks(rotation=45)
plt.show()

# Result statement
print("The most common reasons for taking out a loan are debt consolidation and other personal purposes.")
# Out:
# The most common reasons for taking out a loan are debt consolidation and other personal purposes.

# %% [markdown]
# **Data Preparation**

# %%
# Remove columns
df.drop(columns=['Loan ID','Customer ID'], inplace=True)

# Removing columns with extremely many missing values
df.drop(columns=['Months since last delinquent'], inplace=True)

# %%
# First, I analyzed columns like 'Term' using df['Example'].value_counts(), 
# then converted the non-numeric values to numeric values by renaming them accordingly

# %%
# Convert non numeric values

# %%
df['Loan Status'].value_counts()
# Out:
# Loan Status
# Fully Paid     176191
# Charged Off     64183
# Name: count, dtype: int64

# %%
# Replace values with map()
df['Loan Status'] = df['Loan Status'].map({'Fully Paid': 0, 'Charged Off': 1})

# %%
# Replace values with map()
df['Term'] = df['Term'].map({'Short Term': 0, 'Long Term': 1})
df['Home Ownership'] = df['Home Ownership'].map({'Home Mortgage': 0, 'Rent': 1, 'Own Home': 2, 'HaveMortgage': 3})
df['Purpose'] = df['Purpose'].map({'Debt Consolidation': 0, 'Home Improvements': 1, 'other': 2, 'Other': 3, 'Business Loan': 4, 'Buy a Car': 5, 'Medical Bills': 6, 'Take a Trip': 7 , 'Buy House': 8, 'Educational Expenses': 9})

# %%
# Check the Datatype
print(df['Years in current job'].dtype)
# Out:
# object

# %%
df['Years in current job'].value_counts()
# Out:
# Years in current job
# 10+ years    73965
# 2 years      21972
# < 1 year     19684
# 3 years      19337
# 5 years      16759
# 1 year       15670
# 4 years      15138
# 6 years      13654
# 7 years      13073
# 8 years      11417
# 9 years       9261
# Name: count, dtype: int64

# %%
# Remove plus signs and extract only the numbers
df['Years in current job'] = df['Years in current job'].str.extract('(\d+)')[0]

# Convert < 1 year to 0
df['Years in current job'] = df['Years in current job'].replace('< 1', '0')

# Convert to numeric vlues
df['Years in current job'] = pd.to_numeric(df['Years in current job'], errors='coerce')

# %%
# Create a histogram to visualize the distribution of 'Years in current job'
plt.figure(figsize=(10, 6))
df['Years in current job'].hist(bins=10, edgecolor='black')
plt.title('Distribution of Years in Current Job')
plt.xlabel('Years')
plt.ylabel('Number of Customers')
plt.grid(True)
plt.show()

# %%
# Extract numbers and convert to numeric
df['Monthly Debt'] = df['Monthly Debt'].str.extract('(\d+)')[0]
df['Monthly Debt'] = pd.to_numeric(df['Monthly Debt'], errors='coerce')  # Convert to numeric, handle errors

# %%
# Handling Missing Values

# %%
# Filling the missing values in the columns 
df['Credit Score'] = df['Credit Score'].fillna(df['Credit Score'].mean())
df['Annual Income'] = df['Annual Income'].fillna(df['Annual Income'].mean())
df['Years in current job'] = df['Years in current job'].fillna(df['Years in current job'].median())

# Filling specific columns
df['Bankruptcies'].fillna(0, inplace=True)
df['Tax Liens'].fillna(0, inplace=True)

# %% [raw]
# Alternativ:
# Use inplace=True if you want to make the code more compact and memory-efficient, and you don't need to revert to the original, unmodified data later
#
# df['Credit Score'].fillna(df['Credit Score'].mean(), inplace=True)
# df['Annual Income'].fillna(df['Annual Income'].mean(), inplace=True)
# df['Years in current job'].fillna(df['Years in current job'].median(), inplace=True)
#
# df['Bankruptcies'].fillna(0, inplace=True)
# df['Tax Liens'].fillna(0, inplace=True)

# %%
df.columns
# Out:
# Index(['Loan Status', 'Current Loan Amount', 'Term', 'Credit Score',
#        'Years in current job', 'Home Ownership', 'Annual Income', 'Purpose',
#        'Monthly Debt', 'Years of Credit History', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# Conversion of 'Annual Income' to integers (Integer)
df['Annual Income'] = df['Annual Income'].astype(int)

# %%
# Plotting the distribution of 'Years of Credit History' by 'Loan Status'
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Years of Credit History', hue='Loan Status', multiple='stack', bins=30, kde=True)
plt.title('Years of Credit History and Loan Status')
plt.xlabel('Years of Credit History')
plt.ylabel('Number of Borrowers')
plt.show()

# Result statement
print("The distribution of years of credit history shows that borrowers with longer credit histories tend to have more stable loan statuses.")
# Out:
# The distribution of years of credit history shows that borrowers with longer credit histories tend to have more stable loan statuses.

# %%
plt.figure(figsize=(10, 8))  # Adjust the figure size for better readability
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Blues', fmt='.2f', linewidths=0.5);

# %%
# I identified previously overlooked or hidden values (via the error report) and addressed them immediately

# %%
import numpy as np

# %%
# Replace invalid values like '#VALUE!' with NaN
df.replace(['#VALUE!'], np.nan, inplace=True)  #'other_invalid_values', 'another_invalid_value'

# %%
# Convert all columns to numeric values (non-convertible values become NaN)
df = df.apply(pd.to_numeric, errors='coerce')

# %%
# Handle missing values (NaN) by filling them with the median of each column
df.fillna(df.median(), inplace=True)

# %% [markdown]
# **Feature Engineering**

# %%
# Features in x, Target in y
x = df.drop(['Loan Status'], axis=1)
y = df['Loan Status']

# %% [markdown]
# *Modelling*

# %%
#!pip install xgboost

# %%
# Import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier  # Requires xgboost installation
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

def classification_funct(x, y):
    # Define classifiers
    g = GaussianNB()
    b = BernoulliNB()
    KN = KNeighborsClassifier()
    svc = SVC()
    D = DecisionTreeClassifier()
    R = RandomForestClassifier()
    Log = LogisticRegression()
    XGB = XGBClassifier()
    G = GradientBoostingClassifier()

    # Split the dataset into training and test sets
    x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=13)

    # Initialize classifiers list and their names
    algos = [g, b, KN, svc, D, R, Log, XGB, G]
    algo_names = ['GaussianNB', 'BernoulliNB', 'KNeighborsClassifier', 'SVC', 
                  'DecisionTreeClassifier', 'RandomForestClassifier', 
                  'LogisticRegression', 'XGBClassifier', 'GradientBoostingClassifier']
    
    # Initialize lists to store model performance metrics
    accuracy_scored = []
    precision_scored = []
    recall_scored = []
    f1_scored = []

    # Apply random under-sampling to balance the classes
    RUS = RandomUnderSampler(random_state=42)
    x_RUS, y_RUS = RUS.fit_resample(x_train, y_train)
    
    # Train and evaluate each model
    for model in algos:
        # Fit the model on the resampled training data
        model.fit(x_RUS, y_RUS)
        
        # Predict on the test set
        predict = model.predict(x_test)

        # Append the performance metrics to the respective lists
        accuracy_scored.append(accuracy_score(y_test, predict))
        precision_scored.append(precision_score(y_test, predict, average='binary'))
        recall_scored.append(recall_score(y_test, predict, average='binary'))
        f1_scored.append(f1_score(y_test, predict, average='binary'))
    
    # Create a result DataFrame to store the scores
    result = pd.DataFrame({
        'accuracy_score': accuracy_scored,
        'f1_score': f1_scored,
        'recall_score': recall_scored,
        'precision_score': precision_scored
    }, index=algo_names)

    # Sort the results by accuracy score in descending order
    return result.sort_values('accuracy_score', ascending=False)

# Example usage:
# Assuming X_train and y_train are defined
# result = classification_funct(X_train, y_train)
# print(result)

# %%
classification_funct(x,y)
# Out:
#                             accuracy_score  f1_score  recall_score  \
# RandomForestClassifier            0.718890  0.571711      0.711177
# GradientBoostingClassifier        0.714431  0.566565      0.707456
# XGBClassifier                     0.713116  0.566943      0.711808
# BernoulliNB                       0.686142  0.389552      0.379589
# DecisionTreeClassifier            0.651596  0.496501      0.651129
# KNeighborsClassifier              0.642810  0.486766      0.642046
# LogisticRegression                0.626285  0.480139      0.654157
# GaussianNB                        0.411539  0.472501      0.998991
# SVC                               0.409691  0.471972      1.000000
#
#                             precision_score
# RandomForestClassifier             0.477977
# GradientBoostingClassifier         0.472471
# XGBClassifier                      0.471072
# BernoulliNB                        0.400053
# DecisionTreeClassifier             0.401220
# ...

# %%
# Algo Testler nedendir dusuk score veriyor. Bu sebeb'den bir kac modeli ayri demeyi karar aldim

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB

# %%
g=GaussianNB()
b=BernoulliNB()

# %%
g.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report

# %%
gtahmin=g.predict(x_test)

# %%
accuracy_score(gtahmin,y_test)
# Out:
# 0.41279251170046805

# %%
confusion_matrix(gtahmin,y_test)
# Out:
# array([[ 7064,     7],
#        [28223, 12781]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(gtahmin,y_test),annot=True);

# %%
print(classification_report(gtahmin,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.20      1.00      0.33      7071
#            1       1.00      0.31      0.48     41004
#
#     accuracy                           0.41     48075
#    macro avg       0.60      0.66      0.40     48075
# weighted avg       0.88      0.41      0.45     48075

# %%
# Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
d=DecisionTreeClassifier()

# %%
d.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtahmin=d.predict(x_test)

# %%
print(classification_report(dtahmin,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81     34741
#            1       0.50      0.48      0.49     13334
#
#     accuracy                           0.72     48075
#    macro avg       0.65      0.64      0.65     48075
# weighted avg       0.72      0.72      0.72     48075

# %%
confusion_matrix(dtahmin,y_test)
# Out:
# array([[28289,  6452],
#        [ 6998,  6336]], dtype=int64)

# %%
# Neighbors Model - k-Nearest Neighbors (k-NN)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k=KNeighborsClassifier()

# %%
k.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
ktahmin=k.predict(x_test)

# %%
confusion_matrix(ktahmin,y_test)
# Out:
# array([[31757,  8372],
#        [ 3530,  4416]], dtype=int64)

# %%
print(classification_report(ktahmin,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.79      0.84     40129
#            1       0.35      0.56      0.43      7946
#
#     accuracy                           0.75     48075
#    macro avg       0.62      0.67      0.63     48075
# weighted avg       0.81      0.75      0.77     48075

# %%
# En ici Scoru KNeighborsClassifier modelimiz verdi sonucu 84%
# f1 score sonucumuz normal sartlar'da 85% olmali.
# Model basarili sonuc verdi denebilir ~ 85%

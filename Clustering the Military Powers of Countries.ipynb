# %% [markdown]
# <div style="background-color: darkgreen; padding: 20px; text-align: center; border-radius: 10px;">
#     <h1 style="color: brown; font-weight: bold;">
#         &#8226;&#8226;
#         <span style="color: black;"> Clustering the Military Powers of Countries </span>
#         &#8226;&#8226;
#     </h1>
# </div>

# %% [markdown]
# Bu projenin amacı, ülkelerin askeri güçlerini özelliklerine göre gruplandırmaktır. Kümeleme algoritmaları kullanılarak benzer özelliklere sahip ülkeler tanımlanıp analiz edilmektedir. Böylece, dünyanın ülkelerinin askeri pozisyonlarını anlamış oluyoruz. Bu analiz, ülkelerin askeri kapasitelerini karşılaştırmayı ve savunma stratejilerindeki desenleri tanımlamayı mümkün kılar. Bu sayede jeopolitik dinamikler ve küresel düzeydeki askeri hazırlık hakkında değerli bilgiler elde edilir
# _____________________
# The aim of this project is to group the military forces of individual countries based on their characteristics. Using clustering algorithms, countries with similar traits are identified and analyzed. This allows us to capture the military positions of countries worldwide. This analysis facilitates the comparison of military capacities and the identification of patterns in their defense strategies. It provides valuable insights into geopolitical dynamics and military readiness on a global scale

# %% [markdown]
# **Data Dictionary**
#
# | Column Name                                          | Description                                                   | Turkish Translation                                    |
# |-----------------------------------------------------|---------------------------------------------------------------|--------------------------------------------------------|
# | Military Strength                                   | Military Strength Power Index                                 | Askeri Güç                                             |
# | Aircraft Strength                                   | Aircraft Strength value                                       | Uçak Gücü                                             |
# | Fighter/Interceptor Strength                        | Fighter/Interceptor Strength value                            | Avcı/İnterceptor Gücü                                  |
# | Attack Aircraft Strength                            | Attack Aircraft Strength value                                | Saldırı Uçağı Gücü                                    |
# | Transport Aircraft Fleet Strength                   | Transport Aircraft Fleet Strength value                       | Taşıma Uçağı Filosu Gücü                               |
# | Trainer Aircraft Fleet                              | Trainer Aircraft Fleet value                                  | Eğitim Uçağı Filosu                                    |
# | Helicopter Fleet Strength                           | Helicopter Fleet Strength value                               | Helikopter Filosu Gücü                                 |
# | Attack Helicopter Fleet Strength                    | Attack Helicopter Fleet Strength value                        | Saldırı Helikopter Filosu Gücü                         |
# | Tank Strength                                       | Tank Strength value                                          | Tank Gücü                                             |
# | AFV/APC Strength                                   | AFV/APC Strength value                                       | Zırhlı Araç/Görevci Gücü                               |
# | Self-Propelled Artillery Strength                   | Self-Propelled Artillery Strength value                       | Kendinden Tahrik Edilen Topçu Gücü                    |
# | Towed Artillery Strength                            | Towed Artillery Strength value                                | Çekili Topçu Gücü                                     |
# | Rocket Projector Strength                           | Rocket Projector Strength value                               | Roket Atıcı Gücü                                       |
# | Navy Fleet Strengths                                | Navy Fleet Strength value                                     | Deniz Filosu Gücü                                      |
# | Destroyer Fleet Strength value                      | Destroyer Fleet Strength value                                | Muhrip Filosu Gücü                                     |
# | Frigate Fleet Strength                              | Frigate Fleet Strength value                                  | Fırkateyn Filosu Gücü                                  |
# | Defense Spending Budget                             | Defense Spending Budget value                                 | Savunma Harcama Bütçesi                               |
# | External Debt                                       | External Debt value                                          | Dış Borç                                              |
# | Airport Totals                                      | Airport Totals value                                         | Havaalanı Toplamları                                   |
# | Oil Production                                      | Oil Production value                                         | Petrol Üretimi                                        |
# | Oil Consumption                                     | Oil Consumption value                                        | Petrol Tüketimi                                       |
# | Proven Oil Reserves                                 | Proven Oil Reserves value                                    | Kanıtlanmış Petrol Rezervleri                          |
# | Available Manpower                                   | Available Manpower value                                      | Mevcut İşgücü                                        |
# | Total Population                                    | Total Population value                                       | Toplam Nüfus                                          |
# | Total Square Land Area                              | Total Square Land Area value                                 | Toplam Kara Alanı                                      |
# | Total Coastline Coverage                            | Total Coastline Coverage value                               | Toplam Kıyı Kaplama                                    |
# | Total Waterway Coverage                             | Total Waterway Coverage value                                | Toplam Su Yolu Kaplama                                 |
# | Total Border Coverage                               | Total Border Coverage value                                  | Toplam Sınır Kaplama                                   |

# %% [markdown]
# <img src='https://tgb.gen.tr/dosyalar/28/450642-savunma-sanayi-fuari-kapilarini-ziyaretcilerine-acti/icerik.jpg'>
# <a href='https://classroom.google.com/c/NzIwMjcyMjkxMjgy/a/NzIwMjcyMjkxNDQ2/details' target=_blank>
# Click here for the dataset </a>

# %% [markdown]
# **Import libary**

# %%
import pandas as pd
pd.set_option("display.max_columns",55)
pd.set_option("display.max_rows",None)

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel('World military power.xlsx')

# %% [markdown]
# **Exploratory Data Analysis**

# %%
df.head()
# Out:
#         2020 ranking                     Unnamed: 1  Airforce Strength  \
# 0  Military Strength  Military Strength Power Index  Aircraft Strength
# 1        Afghanistan                         1.3444        Afghanistan
# 2            Albania                         2.3137            Albania
# 3            Algeria                         0.4659            Algeria
# 4             Angola                         0.8379             Angola
#
#                 Unnamed: 3                    Unnamed: 4  \
# 0  Aircraft Strength value  Fighter/Interceptor Strength
# 1                      260                   Afghanistan
# 2                       19                       Albania
# 3                      551                       Algeria
# 4                      295                        Angola
#
#                            Unnamed: 5                Unnamed: 6  \
# 0  Fighter/Interceptor Strength value  Attack Aircraft Strength
# ...

# %%
df.shape
# Out:
# (139, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 60 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   2020 ranking       139 non-null    object
#  1   Unnamed: 1         139 non-null    object
#  2   Airforce Strength  139 non-null    object
#  3   Unnamed: 3         139 non-null    object
#  4   Unnamed: 4         139 non-null    object
#  5   Unnamed: 5         139 non-null    object
#  6   Unnamed: 6         139 non-null    object
#  7   Unnamed: 7         139 non-null    object
#  8   Unnamed: 8         139 non-null    object
#  9   Unnamed: 9         139 non-null    object
#  10  Unnamed: 10        139 non-null    object
#  11  Unnamed: 11        139 non-null    object
#  12  Unnamed: 12        139 non-null    object
#  13  Unnamed: 13        139 non-null    object
#  14  Unnamed: 14        139 non-null    object
#  15  Unnamed: 15        139 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# 2020 ranking          0
# Unnamed: 1            0
# Airforce Strength     0
# Unnamed: 3            0
# Unnamed: 4            0
# Unnamed: 5            0
# Unnamed: 6            0
# Unnamed: 7            0
# Unnamed: 8            0
# Unnamed: 9            0
# Unnamed: 10           0
# Unnamed: 11           0
# Unnamed: 12           0
# Unnamed: 13           0
# Unnamed: 14           0
# Unnamed: 15           0
# Land Strength         0
# Unnamed: 17           0
# Unnamed: 18           0
# Unnamed: 19           0
# Unnamed: 20           0
# Unnamed: 21           0
# Unnamed: 22           0
# Unnamed: 23           0
# Unnamed: 24           0
# Unnamed: 25           0
# Navy Strength        14
# Unnamed: 27          14
# Unnamed: 28          23
# Unnamed: 29          23
# Unnamed: 30          23
# Unnamed: 31          23
# Unnamed: 32          23
# Unnamed: 33          23
# Unnamed: 34          23
# Unnamed: 35          23
# Finances              0
# Unnamed: 37           0
# ...

# %% [markdown]
# **Data Preparation**

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
# first I change the second row as new colum names
df.columns = df.iloc[0]

# Remove the first row and modify the DataFrame in place
df.drop(index=0, inplace=True)

# %%
# Rename the column "Military Strength" to "Country"
df.rename(columns={'Military Strength': 'Country'}, inplace=True)

# %%
# Remove columns
df.drop(columns=['Aircraft Strength','Fighter/Interceptor Strength','Attack Aircraft Strength','Transport Aircraft Fleet Strength',
                 'Trainer Aircraft Fleet','Helicopter Fleet Strength','Attack Helicopter Fleet Strength','Tank Strength','AFV/APC Strength',
                 'Self-Propelled Artillery Strength','Towed Artillery Strength','Rocket Projector Strength','Navy Fleet Strengths','Aircraft Carrier Fleet Strength',
                 'Submarine Fleet Strength','Destroyer Fleet Strength','Frigate Fleet Strength','defense spending budget',
                 'External Debt','Airport Totals','Oil Production','Oil Consumption','Proven Oil Reserves','Available Manpower',
                 'Total Population','Total Square Land Area','Total Coastline Coverage','Total Waterway Coverage','Total Border Coverage'
                ], inplace=True)

# %%
df.shape
# Out:
# (138, 31)

# %%
# Remove the commas from the columns and convert the values to floating-point numbers

df['defense spending budget value'] = df['defense spending budget value'].str.replace(',', '').astype(float)
df['External Debt value'] = df['External Debt value'].str.replace(',', '').astype(float)
df['Oil Production value'] = df['Oil Production value'].str.replace(',', '').astype(float)
df['Oil Consumption value'] = df['Oil Consumption value'].str.replace(',', '').astype(float)
df['Proven Oil Reserves value'] = df['Proven Oil Reserves value'].str.replace(',', '').astype(float)
df['Available Manpower value'] = df['Available Manpower value'].str.replace(',', '').astype(float)
df['Total Population value'] = df['Total Population value'].str.replace(',', '').astype(float)
df['Total Square Land Area value'] = df['Total Square Land Area value'].str.replace(',', '').astype(float)
df['Total Coastline Coverage value'] = df['Total Coastline Coverage value'].str.replace(',', '').astype(float)
df['Total Waterway Coverage value'] = df['Total Waterway Coverage value'].str.replace(',', '').astype(float)

# %%
# bazi degerler float cevrildi
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 1 to 138
# Data columns (total 31 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Country                                  138 non-null    object
#  1   Military Strength Power Index            138 non-null    object
#  2   Aircraft Strength value                  138 non-null    object
#  3   Fighter/Interceptor Strength value       138 non-null    object
#  4   Attack Aircraft Strength value           138 non-null    object
#  5   Transport Aircraft Fleet Strength value  138 non-null    object
#  6   Trainer Aircraft Fleet value             138 non-null    object
#  7   Helicopter Fleet Strength value          138 non-null    object
#  8   Attack Helicopter Fleet Strength value   138 non-null    object
#  9   Tank Strength value                      138 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# 0
# Country                                      0
# Military Strength Power Index                0
# Aircraft Strength value                      0
# Fighter/Interceptor Strength value           0
# Attack Aircraft Strength value               0
# Transport Aircraft Fleet Strength value      0
# Trainer Aircraft Fleet value                 0
# Helicopter Fleet Strength value              0
# Attack Helicopter Fleet Strength value       0
# Tank Strength value                          0
# AFV/APC Strength value                       0
# Self-Propelled Artillery Strength value      0
# Towed Artillery Strength value               0
# Rocket Projector Strength value              0
# Navy Fleet Strengths value                  14
# Aircraft Carrier Fleet Strength value       23
# Submarine Fleet Strength value              23
# Destroyer Fleet Strength value              23
# Frigate Fleet Strength value                23
# defense spending budget value                0
# ...

# %%
# Handling Missing Values

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# 0
# Country                                    0
# Military Strength Power Index              0
# Aircraft Strength value                    0
# Fighter/Interceptor Strength value         0
# Attack Aircraft Strength value             0
# Transport Aircraft Fleet Strength value    0
# Trainer Aircraft Fleet value               0
# Helicopter Fleet Strength value            0
# Attack Helicopter Fleet Strength value     0
# Tank Strength value                        0
# AFV/APC Strength value                     0
# Self-Propelled Artillery Strength value    0
# Towed Artillery Strength value             0
# Rocket Projector Strength value            0
# Navy Fleet Strengths value                 0
# Aircraft Carrier Fleet Strength value      0
# Submarine Fleet Strength value             0
# Destroyer Fleet Strength value             0
# Frigate Fleet Strength value               0
# defense spending budget value              0
# External Debt value                        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 1 to 138
# Data columns (total 31 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Country                                  138 non-null    object
#  1   Military Strength Power Index            138 non-null    float64
#  2   Aircraft Strength value                  138 non-null    int64
#  3   Fighter/Interceptor Strength value       138 non-null    int64
#  4   Attack Aircraft Strength value           138 non-null    int64
#  5   Transport Aircraft Fleet Strength value  138 non-null    int64
#  6   Trainer Aircraft Fleet value             138 non-null    int64
#  7   Helicopter Fleet Strength value          138 non-null    int64
#  8   Attack Helicopter Fleet Strength value   138 non-null    int64
#  9   Tank Strength value                      138 non-null    int64
# ...

# %% [markdown]
# **Modelling**

# %%
x=df.drop(['Country'],axis=1)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
model=KMeans(4)

# %%
model=model.fit(x)

# %%
tahmin=model.predict(x)

# %%
x['cluster']=tahmin

# %%
x
# Out:
# 0    Military Strength Power Index  Aircraft Strength value  \
# 1                           1.3444                      260
# 2                           2.3137                       19
# 3                           0.4659                      551
# 4                           0.8379                      295
# 5                           0.6521                      227
# 6                           2.1251                       64
# 7                           0.3225                      464
# 8                           0.9568                      120
# 9                           0.9463                      147
# 10                          1.8547                      109
# 11                          0.7066                      177
# 12                          0.8179                      202
# 13                          1.0499                      148
# 14                         10.1681                        2
# 15                          0.9942                       69
# ...

# %%
silhouette_score(x,tahmin)
# Out:
# 0.862295725499467

# %%
wcss=[]
ss=[]
for i in range(2,10): #en az iki olmak zorunda o yüzden 1
    model=KMeans(i)
    model=model.fit(x)
    tahmin=model.predict(x)
    ss1=silhouette_score(x,tahmin)
    ss.append(ss1)
    print(ss1)
    wcss.append(model.inertia_)
# Out:
# 0.9227153206135542
# 0.8891169511672569
# 0.8671436271435957
# 0.867519554074208
# 0.8409467792579314
# 0.8320618154867462
# 0.7847423623921217
# 0.6818555400716981

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.scatter(x['Military Strength Power Index'], x['Oil Production value'], c=tahmin)
plt.colorbar();
plt.xlabel("km")
plt.ylabel('üretim');

# %%
import seaborn as sns

# %%
sns.lineplot(x=range(2,10),y=wcss,marker='*');

# %%
from yellowbrick.cluster import KElbowVisualizer

# %%
# KMeans Clustering

# %%
km=KMeans()
vis=KElbowVisualizer(km,k=(2,10))
vis.fit(x)
vis.show();

# %%
# Hierachical Clustering

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
data=linkage(x, method='ward', metric='euclidean')

# %%
plt.figure(figsize=(25, 6))
dendrogram(data);

# %%
# Auflistung der Länder und ihrer militärischen Stärken in jedem Cluster
cluster_labels = model.labels_
df['Cluster'] = cluster_labels

for i in range(4):
    print(f"Cluster {i+1}:")
    print(df[df['Cluster'] == i]['Country'].tolist())
    print()

# von Saliha Dil
# Out:
# Cluster 1:
# ...

# %%
# The listing of countries in each cluster illustrates how the military strengths of individual nations can be grouped
# USA and UK form their own group

# %%
# Poe benzer birsey cikardi
cluster_labels = model.labels_
df['Cluster'] = cluster_labels

for i in range(max(cluster_labels) + 1):  # Küme sayısına göre döngüyü ayarlıyoruz
    print(f"Cluster {i + 1}:")
    countries_in_cluster = df[df['Cluster'] == i]['Country'].tolist()
    print(countries_in_cluster)
    print()
# Out:
# Cluster 1:
# ...

# %%
# max. cluster sayisini aldi sanirim. sonra güce göre veya neye göre kümeledi net söyleyemiyorum
